# %%
# %pylab inline
import numpy as np
import GPy
from matplotlib import pyplot as plt
import scipy.stats.stats 
from numpy import genfromtxt
from pandas import DataFrame, concat
import pandas as pd
from matplotlib.pyplot import *
from scipy.stats.stats import pearsonr as cor
from sklearn.preprocessing import scale
from pylab import pcolor, show, colorbar, xticks, yticks
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/GPy-0.6.0-py2.7.egg/GPy/util/linalg.py:48: UserWarning: warning: caught this exception:'module' object has no attribute '_dotblas'
#   warnings.warn("warning: caught this exception:" + str(e))

# %%
## Load the features
# load features and extract what we need
df_features_all   = pd.read_csv('./features_mouse_processing/processed/features_genes.csv',sep=' ')
df_features_all   = df_features_all.drop('index',1)

# In principle we don't use the Codon context, so we only keep the rest of the features.
df_ids       = df_features_all.iloc[:,0:1] 
df_features1 = df_features_all.iloc[:,1:129] 
df_cc        = df_features_all.iloc[:,129:4225]
df_features2 = df_features_all.iloc[:,4225:]

df_features = concat([df_ids, df_features1,df_features2], axis=1)
df_features   = df_features.replace([np.inf, -np.inf], np.nan)
df_features   = df_features.dropna(0)

# %%
## load and merge the datasets that we need for the model
# load translation rates
df_data      = pd.read_csv('./data_cho/data_cleaned.csv', sep='\t').dropna()

# %%
# merge of the datasets
df_full       = pd.merge(df_features, df_data, on='gene_ID', how='inner')

# %%
df_data
# Out:
#        gene_ID  protein               rna protein_degradation        rna_hl  \
# 0         rna4     3234  1068179,40023831              295248  0,0106489287
# 1         rna8     3887  15067,1182039298             34,6658  0,0633113373
# 2        rna21     1520  56557,3461145356             71,7153   0,021134605
# 3        rna30     2678  3517716,81139877              158528  0,0119120397
# 4        rna50     3365  37229,6190001766             21,7467  0,0340604457
# 5        rna58     3449  19243,8898016582             5,74103  0,0210414003
# 6        rna67     3575  156286,804523246             25,5537   0,037803224
# 7        rna69     3617   14360,637984572             15,2547  0,0304938721
# 8        rna71     3651  245281,531605456             80,1253   0,014255814
# 9        rna72     3665  17242,1093610814             20,7354  0,0236836574
# 10       rna76     3735   1341,7802611792             5,09016  0,0314972402
# 11       rna89     3936   66035,183401041             33,4346  0,0244377738
# 12       rna93     3984  25725,4839591885               17628  0,0156087094
# 13      rna106     4195  13477,0150855579               19224  0,0263381126
# 14      rna110       42  11583,8046530336             7,76346  0,0207709693
# 15      rna123      131  26397,9292426932             13,5572  0,0207926319
# 16      rna124      150  610258,955510072             69,3759  0,0141771843
# 17      rna130      236  13374,3068958529             73,4092  0,0230623155
# 18      rna144      401   7621,2364022747             21,3972  0,0292378737
# 19      rna149      440   2793,4025534366             7,95008  0,0458918004
# 20      rna151      485  15201,6797692804             47,0695  0,0366586053
# 21      rna161      631   8069,9957524127             31,9004   0,039255987
# 22      rna167      693  47449,8245777001             72,3283  0,0265594542
# 23      rna171      768  19791,6133777435             16,1669  0,0257461931
# 24      rna220     1371   1719,0697240443              102001  0,0345598991
# 25      rna225     1454  12736,3623141469             44,1989   0,002896006
# 26      rna227     1480  10000,8087638936             26,5634  0,0168817126
# 27      rna234     1598  22305,5689747085              120528  0,2037384934
# 28      rna235     1616  168302,938957676             48,9296  0,0228888068
# 29      rna239     1676  53287,2730597805             98,4945  0,0248089491
# ...        ...      ...               ...                 ...           ...
# 2892  rna27063     2170  88230,2553545736              134353  0,0857294257
